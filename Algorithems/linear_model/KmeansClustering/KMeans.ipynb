# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)

x1 = np.random.normal(loc=5, scale=1, size=(100,2))
x2 = np.random.normal(loc=10, scale=1, size=(100,2))
x = np.concatenate([x1, x2])

plt.scatter(x[:,0], x[:,1])
plt.show()
